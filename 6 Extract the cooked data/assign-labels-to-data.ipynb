# %%
INPUT_POSTING_OFFICE_ONLY_OFFICE_CODING_PATH = "../../CGED DATA/posting_office_only_office_coding.xlsx"
INPUT_POSTING_OFFICE_ADDR_OFFICE_CODING_PATH = "../../CGED DATA/posting_office_addr_office_coding.xlsx"
INPUT_POSTING_OFFICE_ADDR_ADDR_CODING_PATH = "../../CGED DATA/posting_office_addr_addr_coding.xlsx"
INPUT_CODE_BIOG_ADDR_RESULT_PATH = "../../CGED DATA/code_biog_addr_result.xlsx"
INPUT_CODE_OFFICE_ONLY_RESULT_PATH = "../../CGED DATA/code_office_only_result.xlsx"
INPUT_CODE_ADDR_FOR_OFFICE_WITH_ADDR_RESULT_PATH = "../../CGED DATA/code_addr_for_office_with_addr_result.xlsx"
INPUT_CODE_OFFICE_FOR_OFFICE_WITH_ADDR_RESULT_PATH = "../../CGED DATA/code_office_for_office_with_addr_result.xlsx"
INPUT_DATA = "../../CGED DATA/CGED-Q_new_person_essential_columns_only_variences_cleaned.csv"
OUTPUT_DATA = "../../CGED DATA/CGED-Q_new_person_essential_columns_only_variences_cleaned_coded.csv"
OUTPUT_SAMPEL_DATA = "../../CGED DATA/CGED-Q_new_person_essential_columns_only_variences_cleaned_coded_sample.xlsx"

# %% [markdown]
# ## Import data

# %%
import pandas as pd

df = pd.read_csv(INPUT_DATA, sep="\t")
df = df.fillna("")
df
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 2283234  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2283235  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 2283236  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2283237  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2283238  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... ren_sheng ren_xian minzu qifen chushen_1  \
# 0           阿迷州              學正  ...        雲南                             舉人
# 1           阿迷州              學正  ...        雲南                             舉人
# 2           阿迷州              學正  ...                雲南府                    舉人
# 3         翰林院編修              空白  ...        貴州       貴築
# 4         翰林院編修              空白  ...        貴州       貴築                    進士
# ...         ...     ...     ...  ...       ...      ...   ...   ...       ...
# 2283234    浙江衛所     金衢所    領運千總  ...        湖北       孝感                    武舉
# 2283235    江南衛所     江淮衛  三幫領運千總  ...        湖北                             武舉
# 2283236     甕安縣              典史  ...        浙江       上虞
# 2283237     瑞昌縣           肇陳口巡检  ...        順天       大興                    監生
# 2283238                    盐捕州判  ...        湖北       江夏                    拔貢
#
#         ganzhi_1 banben_nianhao banben_niandai banben_jijie     person_id
# 0                            道光           20.0            夏  1.839413e+11
# 1                            道光           19.0            冬  1.839413e+11
# 2                            道光           20.0            秋  1.839413e+11
# 3             庚戌             同治            6.0            秋  1.851202e+11
# 4                            同治            7.0            秋  1.851202e+11
# ...          ...            ...            ...          ...           ...
# 2283234                      嘉慶            2.0            春  1.788105e+11
# 2283235                      乾隆           53.0            春  1.788105e+11
# 2283236                      乾隆           25.0            冬  1.760413e+11
# 2283237                      乾隆           25.0            冬  1.760406e+11
# 2283238                      乾隆           25.0            冬  1.760408e+11
#
# [2283239 rows x 24 columns]

# %%
## Create simplified Chinese columns

from char_converter import CharConverter

column_name_pairs = {"diqu":"diqu_sim",
                     "jigou_1":"jigou_1_sim",
                     "jigou_2":"jigou_2_sim",
                     "jigou_3":"jigou_3_sim",
                     "guanzhi":"guanzhi_sim",
                     "ren_sheng":"ren_sheng_sim",
                     "ren_xian":"ren_xian_sim",}
converter = CharConverter('v2s')
for column_name, new_column_name in column_name_pairs.items():
    df[new_column_name] = df[column_name].apply(converter.convert)
df
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 2283234  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2283235  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 2283236  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2283237  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2283238  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... banben_niandai banben_jijie  \
# 0           阿迷州              學正  ...           20.0            夏
# 1           阿迷州              學正  ...           19.0            冬
# 2           阿迷州              學正  ...           20.0            秋
# 3         翰林院編修              空白  ...            6.0            秋
# 4         翰林院編修              空白  ...            7.0            秋
# ...         ...     ...     ...  ...            ...          ...
# 2283234    浙江衛所     金衢所    領運千總  ...            2.0            春
# 2283235    江南衛所     江淮衛  三幫領運千總  ...           53.0            春
# 2283236     甕安縣              典史  ...           25.0            冬
# 2283237     瑞昌縣           肇陳口巡检  ...           25.0            冬
# 2283238                    盐捕州判  ...           25.0            冬
#
#             person_id diqu_sim jigou_1_sim jigou_2_sim jigou_3_sim  \
# 0        1.839413e+11      云南省         临安府         阿迷州
# 1        1.839413e+11      云南省         临安府         阿迷州
# 2        1.839413e+11      云南省         临安府         阿迷州
# 3        1.851202e+11       京师       翰林院衙门       翰林院编修
# 4        1.851202e+11       京师       翰林院衙门       翰林院编修
# ...               ...      ...         ...         ...         ...
# 2283234  1.788105e+11      江南省      总漕部院衙门        浙江卫所         金衢所
# 2283235  1.788105e+11      江苏省      总漕部院衙门        江南卫所         江淮卫
# 2283236  1.760413e+11      贵州省         平越府         罋安县
# 2283237  1.760406e+11      江西省         九江府         瑞昌县
# 2283238  1.760408e+11      湖南省          郴州
#
#         guanzhi_sim ren_sheng_sim ren_xian_sim
# 0                学正            云南
# 1                学正            云南
# 2                学正                        云南府
# 3                空白            贵州           贵筑
# 4                空白            贵州           贵筑
# ...             ...           ...          ...
# 2283234        领运千总            湖北           孝感
# 2283235      三帮领运千总            湖北
# 2283236          典史            浙江           上虞
# 2283237       肇陈口巡检            顺天           大兴
# 2283238        盐捕州判            湖北           江夏
#
# [2283239 rows x 31 columns]

# %% [markdown]
# ## Load BIOG_ADDR coding result

# %%
biog_addr_result = pd.read_excel(INPUT_CODE_BIOG_ADDR_RESULT_PATH)
biog_addr_result = biog_addr_result.fillna("")
biog_addr_result
# Out:
#         id dy addr_name addr_belong time cbdb_id            match_type  \
# 0        1  清        云南                   7206.0  excat_without_belong
# 1        2  清       云南府                   8915.0  excat_without_belong
# 2        3  清        贵筑          贵州       8879.0     exact_with_belong
# 3        4  清        邛州          四川       8736.0   partial_with_belong
# 4        5  清        卬州          四川                            unknown
# ...    ... ..       ...         ...  ...     ...                   ...
# 8764  8765  清        澂江          云南                            unknown
# 8765  8766  清       丽江府          云南       8934.0     exact_with_belong
# 8766  8767  清        慈利                   8361.0  excat_without_belong
# 8767  8768  清        阳湖          安徽       7531.0  excat_without_belong
# 8768  8769  清        雒容                   8608.0  excat_without_belong
#
#      cbdb_addr_name cbdb_belong
# 0                云南
# 1               云南府
# 2                贵筑         贵州省
# 3         邛州直隶州直辖地方         四川省
# 4
# ...             ...         ...
# 8764
# 8765            丽江府         云南省
# 8766             慈利
# 8767             阳湖
# 8768             雒容
#
# [8769 rows x 9 columns]

# %%
exact_flag = ["excat_without_belong", "exact_with_belong", "exact"]
biog_addr_exact_result = biog_addr_result[biog_addr_result["match_type"].isin(exact_flag)]
biog_addr_exact_result
# Out:
#         id dy addr_name addr_belong time cbdb_id            match_type  \
# 0        1  清        云南                   7206.0  excat_without_belong
# 1        2  清       云南府                   8915.0  excat_without_belong
# 2        3  清        贵筑          贵州       8879.0     exact_with_belong
# 7        8  清        长安          陕西       8940.0     exact_with_belong
# 9       10  清       绥定府                   8797.0  excat_without_belong
# ...    ... ..       ...         ...  ...     ...                   ...
# 8761  8762  清       汉阳府          江西       8206.0  excat_without_belong
# 8765  8766  清       丽江府          云南       8934.0     exact_with_belong
# 8766  8767  清        慈利                   8361.0  excat_without_belong
# 8767  8768  清        阳湖          安徽       7531.0  excat_without_belong
# 8768  8769  清        雒容                   8608.0  excat_without_belong
#
#      cbdb_addr_name cbdb_belong
# 0                云南
# 1               云南府
# 2                贵筑         贵州省
# 7                长安         陕西省
# 9               绥定府
# ...             ...         ...
# 8761            汉阳府
# 8765            丽江府         云南省
# 8766             慈利
# 8767             阳湖
# 8768             雒容
#
# [4905 rows x 9 columns]

# %% [markdown]
# ### Match the exact match biographical address coding result with data
#
# - Using addr_name to match ren_xian_sim and using addr_belong to match diqu_sim together,
# - add cbdb_id to the result rename it as cbdb_biog_addr_id,
# - add cbdb_addr_name to the result, rename it as cbdb_biog_addr_name
# - add cbdb_belong to the result, rename it as cbdb_biog_addr_belong

# %%
biog_addr_exact_result = biog_addr_exact_result.rename(columns={"cbdb_id":"cbdb_biog_addr_id", "cbdb_addr_name":"cbdb_biog_addr_name", "cbdb_belong":"cbdb_biog_addr_belong"})
biog_addr_exact_result = biog_addr_exact_result.rename(columns={"addr_name":"ren_xian_sim", "addr_belong":"ren_sheng_sim"})
biog_addr_exact_result
# Out:
#         id dy ren_xian_sim ren_sheng_sim time cbdb_biog_addr_id  \
# 0        1  清           云南                               7206.0
# 1        2  清          云南府                               8915.0
# 2        3  清           贵筑            贵州                 8879.0
# 7        8  清           长安            陕西                 8940.0
# 9       10  清          绥定府                               8797.0
# ...    ... ..          ...           ...  ...               ...
# 8761  8762  清          汉阳府            江西                 8206.0
# 8765  8766  清          丽江府            云南                 8934.0
# 8766  8767  清           慈利                               8361.0
# 8767  8768  清           阳湖            安徽                 7531.0
# 8768  8769  清           雒容                               8608.0
#
#                 match_type cbdb_biog_addr_name cbdb_biog_addr_belong
# 0     excat_without_belong                  云南
# 1     excat_without_belong                 云南府
# 2        exact_with_belong                  贵筑                   贵州省
# 7        exact_with_belong                  长安                   陕西省
# 9     excat_without_belong                 绥定府
# ...                    ...                 ...                   ...
# 8761  excat_without_belong                 汉阳府
# 8765     exact_with_belong                 丽江府                   云南省
# 8766  excat_without_belong                  慈利
# 8767  excat_without_belong                  阳湖
# 8768  excat_without_belong                  雒容
#
# [4905 rows x 9 columns]

# %%
biog_addr_exact_result = biog_addr_exact_result[["ren_xian_sim", "ren_sheng_sim", "cbdb_biog_addr_id", "cbdb_biog_addr_name", "cbdb_biog_addr_belong"]]
biog_addr_exact_result
# Out:
#      ren_xian_sim ren_sheng_sim cbdb_biog_addr_id cbdb_biog_addr_name  \
# 0              云南                          7206.0                  云南
# 1             云南府                          8915.0                 云南府
# 2              贵筑            贵州            8879.0                  贵筑
# 7              长安            陕西            8940.0                  长安
# 9             绥定府                          8797.0                 绥定府
# ...           ...           ...               ...                 ...
# 8761          汉阳府            江西            8206.0                 汉阳府
# 8765          丽江府            云南            8934.0                 丽江府
# 8766           慈利                          8361.0                  慈利
# 8767           阳湖            安徽            7531.0                  阳湖
# 8768           雒容                          8608.0                  雒容
#
#      cbdb_biog_addr_belong
# 0
# 1
# 2                      贵州省
# 7                      陕西省
# 9
# ...                    ...
# 8761
# 8765                   云南省
# 8766
# 8767
# 8768
#
# [4905 rows x 5 columns]

# %%
df_new = pd.merge(df, biog_addr_exact_result, on=["ren_xian_sim", "ren_sheng_sim"], how="left")
df_new
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 2603899  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2603900  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 2603901  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2603902  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2603903  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... diqu_sim jigou_1_sim jigou_2_sim  \
# 0           阿迷州              學正  ...      云南省         临安府         阿迷州
# 1           阿迷州              學正  ...      云南省         临安府         阿迷州
# 2           阿迷州              學正  ...      云南省         临安府         阿迷州
# 3         翰林院編修              空白  ...       京师       翰林院衙门       翰林院编修
# 4         翰林院編修              空白  ...       京师       翰林院衙门       翰林院编修
# ...         ...     ...     ...  ...      ...         ...         ...
# 2603899    浙江衛所     金衢所    領運千總  ...      江南省      总漕部院衙门        浙江卫所
# 2603900    江南衛所     江淮衛  三幫領運千總  ...      江苏省      总漕部院衙门        江南卫所
# 2603901     甕安縣              典史  ...      贵州省         平越府         罋安县
# 2603902     瑞昌縣           肇陳口巡检  ...      江西省         九江府         瑞昌县
# 2603903                    盐捕州判  ...      湖南省          郴州
#
#         jigou_3_sim guanzhi_sim ren_sheng_sim ren_xian_sim cbdb_biog_addr_id  \
# 0                            学正            云南                            NaN
# 1                            学正            云南                            NaN
# 2                            学正                        云南府            8915.0
# 3                            空白            贵州           贵筑            8879.0
# 4                            空白            贵州           贵筑            8879.0
# ...             ...         ...           ...          ...               ...
# 2603899         金衢所        领运千总            湖北           孝感            8213.0
# 2603900         江淮卫      三帮领运千总            湖北                            NaN
# 2603901                      典史            浙江           上虞            7687.0
# 2603902                   肇陈口巡检            顺天           大兴            7213.0
# 2603903                    盐捕州判            湖北           江夏            8215.0
#
#         cbdb_biog_addr_name cbdb_biog_addr_belong
# 0                       NaN                   NaN
# 1                       NaN                   NaN
# 2                       云南府
# 3                        贵筑                   贵州省
# 4                        贵筑                   贵州省
# ...                     ...                   ...
# 2603899                  孝感                   湖北省
# 2603900                 NaN                   NaN
# 2603901                  上虞                   浙江省
# 2603902                  大兴                   顺天府
# 2603903                  江夏                   湖北省
#
# [2603904 rows x 34 columns]

# %%
# count how many cbdb_biog_addr_id is not null
df_new[df_new["cbdb_biog_addr_id"].notnull()]
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# 43       1864.25     2.0  11743.0      1513979.0  四川省           定水     敘永廳
# 44       1864.25     2.0  11743.0      1513979.0  四川省           定水     敘永廳
# ...          ...     ...      ...            ...  ...          ...     ...
# 2603898  1797.75     4.0   5010.0       158277.0  江南省               總漕部院衙門
# 2603899  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2603901  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2603902  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2603903  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... diqu_sim jigou_1_sim jigou_2_sim  \
# 2           阿迷州              學正  ...      云南省         临安府         阿迷州
# 3         翰林院編修              空白  ...       京师       翰林院衙门       翰林院编修
# 4         翰林院編修              空白  ...       京师       翰林院衙门       翰林院编修
# 43          永寧縣           縣丞駐赤水  ...      四川省         叙永厅         永宁县
# 44          永寧縣           縣丞駐赤水  ...      四川省         叙永厅         永宁县
# ...         ...     ...     ...  ...      ...         ...         ...
# 2603898    浙江衛所     金衢所    領運千總  ...      江南省      总漕部院衙门        浙江卫所
# 2603899    浙江衛所     金衢所    領運千總  ...      江南省      总漕部院衙门        浙江卫所
# 2603901     甕安縣              典史  ...      贵州省         平越府         罋安县
# 2603902     瑞昌縣           肇陳口巡检  ...      江西省         九江府         瑞昌县
# 2603903                    盐捕州判  ...      湖南省          郴州
#
#         jigou_3_sim guanzhi_sim ren_sheng_sim ren_xian_sim cbdb_biog_addr_id  \
# 2                            学正                        云南府            8915.0
# 3                            空白            贵州           贵筑            8879.0
# 4                            空白            贵州           贵筑            8879.0
# 43                        县丞驻赤水            陕西           长安            8940.0
# 44                        县丞驻赤水            陕西           长安            8940.0
# ...             ...         ...           ...          ...               ...
# 2603898         金衢所        领运千总            湖北           孝感            8213.0
# 2603899         金衢所        领运千总            湖北           孝感            8213.0
# 2603901                      典史            浙江           上虞            7687.0
# 2603902                   肇陈口巡检            顺天           大兴            7213.0
# 2603903                    盐捕州判            湖北           江夏            8215.0
#
#         cbdb_biog_addr_name cbdb_biog_addr_belong
# 2                       云南府
# 3                        贵筑                   贵州省
# 4                        贵筑                   贵州省
# 43                       长安                   陕西省
# 44                       长安                   陕西省
# ...                     ...                   ...
# 2603898                  孝感                   湖北省
# 2603899                  孝感                   湖北省
# 2603901                  上虞                   浙江省
# 2603902                  大兴                   顺天府
# 2603903                  江夏                   湖北省
#
# [1797676 rows x 34 columns]

# %% [markdown]
# ## Load office only result

# %%
posting_office_only_result = pd.read_excel(INPUT_CODE_OFFICE_ONLY_RESULT_PATH)
posting_office_only_result = posting_office_only_result.fillna("")
posting_office_only_result
# Out:
#        office_id                    office_name office_dy  cbdb_office_id  \
# 0              0                           刑部主事         清           86386
# 1              1                      户部主事广西司行走         清           82595
# 2              2                           礼部主事         清           83726
# 3              3                         钦天监灵台郎         清           83874
# 4              4                        鸿胪寺额外序班         清           81256
# ...          ...                            ...       ...             ...
# 19234      10695   京师各级审判厅检察厅京师地方检察厅额外厅员候补从六品推检         清           81256
# 19235      10696  京师高等审判厅京师地方检察厅额外厅员额外厅员候补从六品推检         清           81256
# 19236      10708                  军咨处第一厅第四科兼署科长         清           80079
# 19237      10709                  军咨府第一厅第四科兼署科长         清           80079
# 19238      10710          户部仓场总督各仓监督大通桥监督刑部候补郎中         清           80561
#
#       cbdb_office_name match_type
# 0                 刑部主事      exact
# 1                 户部主事    partial
# 2                 礼部主事      exact
# 3                  灵台郎    partial
# 4                   额外    partial
# ...                ...        ...
# 19234               额外    partial
# 19235               额外    partial
# 19236                署    partial
# 19237                署    partial
# 19238             仓场总督    partial
#
# [19239 rows x 6 columns]

# %%
posting_office_only_exact_result = posting_office_only_result[posting_office_only_result["match_type"].isin(exact_flag)]
posting_office_only_exact_result = posting_office_only_exact_result.drop(columns=["office_name", "office_dy", "match_type", "office_id"])
posting_office_only_exact_result = posting_office_only_exact_result.drop_duplicates("cbdb_office_name")
posting_office_only_exact_result = posting_office_only_exact_result.rename(columns={"cbdb_office_name":"cbdb_office_name_sim"})
posting_office_only_exact_result
# Out:
#        cbdb_office_id cbdb_office_name_sim
# 0               86386                 刑部主事
# 2               83726                 礼部主事
# 7               82595                 户部主事
# 8               86368                刑部员外郞
# 21              86301                 刑部郎中
# ...               ...                  ...
# 14571           83712            礼部仪制司额外主事
# 14729           85596            外务部考工司员外郎
# 15128           85597            外务部榷算司员外郎
# 17301           83800            吏部验封司额外主事
# 17537           83731           礼部铸印局掌印员外郎
#
# [329 rows x 2 columns]

# %% [markdown]
# # Load source data for office only

# %%
posting_office_only_office_source = pd.read_excel(INPUT_POSTING_OFFICE_ONLY_OFFICE_CODING_PATH)
posting_office_only_office_source = posting_office_only_office_source.fillna("")
posting_office_only_office_source
# Out:
#        jigou_1  jigou_2 jigou_3      guanzhi     id dy  \
# 0           刑部     額外司員                   主事      0  清
# 1           戶部     額外司員              主事廣西司行走      1  清
# 2           禮部     額外司員                   主事      2  清
# 3          欽天監      天文科                  靈臺郎      3  清
# 4          鴻臚寺     額外序班                 額外序班      4  清
# ...        ...      ...     ...          ...    ... ..
# 22158  京師高等審判廳  京師地方檢察廳    額外廳員  額外廳員候補從六品推檢  10696  清
# 22159      軍諮處      第一廳     第四科         兼署科長  10708  清
# 22160      軍諮府      第一廳     第四科         兼署科長  10709  清
# 22161       戶部     倉場總督    各倉監督  大通橋監督刑部候補郎中  10710  清
# 22162      陸軍部      軍衡司     賞賚科    科員陸軍步隊協軍校  10727  清
#
#                          guanzhi_ext
# 0                               刑部主事
# 1                          戶部主事廣西司行走
# 2                               禮部主事
# 3                             欽天監靈臺郎
# 4                            鴻臚寺額外序班
# ...                              ...
# 22158  京師高等審判廳京師地方檢察廳額外廳員額外廳員候補從六品推檢
# 22159                  軍諮處第一廳第四科兼署科長
# 22160                  軍諮府第一廳第四科兼署科長
# 22161          戶部倉場總督各倉監督大通橋監督刑部候補郎中
# 22162             陸軍部軍衡司賞賚科科員陸軍步隊協軍校
#
# [22163 rows x 7 columns]

# %%
posting_office_only_office_source = posting_office_only_office_source.rename(columns={"guanzhi_ext":"cbdb_office_name"})
posting_office_only_office_source = posting_office_only_office_source.drop(columns=["dy"])
posting_office_only_office_source["cbdb_office_name_sim"] = posting_office_only_office_source["cbdb_office_name"].apply(converter.convert)
posting_office_only_office_source
# Out:
#        jigou_1  jigou_2 jigou_3      guanzhi     id  \
# 0           刑部     額外司員                   主事      0
# 1           戶部     額外司員              主事廣西司行走      1
# 2           禮部     額外司員                   主事      2
# 3          欽天監      天文科                  靈臺郎      3
# 4          鴻臚寺     額外序班                 額外序班      4
# ...        ...      ...     ...          ...    ...
# 22158  京師高等審判廳  京師地方檢察廳    額外廳員  額外廳員候補從六品推檢  10696
# 22159      軍諮處      第一廳     第四科         兼署科長  10708
# 22160      軍諮府      第一廳     第四科         兼署科長  10709
# 22161       戶部     倉場總督    各倉監督  大通橋監督刑部候補郎中  10710
# 22162      陸軍部      軍衡司     賞賚科    科員陸軍步隊協軍校  10727
#
#                     cbdb_office_name           cbdb_office_name_sim
# 0                               刑部主事                           刑部主事
# 1                          戶部主事廣西司行走                      户部主事广西司行走
# 2                               禮部主事                           礼部主事
# 3                             欽天監靈臺郎                         钦天监灵台郎
# 4                            鴻臚寺額外序班                        鸿胪寺额外序班
# ...                              ...                            ...
# 22158  京師高等審判廳京師地方檢察廳額外廳員額外廳員候補從六品推檢  京师高等审判厅京师地方检察厅额外厅员额外厅员候补从六品推检
# 22159                  軍諮處第一廳第四科兼署科長                  军咨处第一厅第四科兼署科长
# 22160                  軍諮府第一廳第四科兼署科長                  军咨府第一厅第四科兼署科长
# 22161          戶部倉場總督各倉監督大通橋監督刑部候補郎中          户部仓场总督各仓监督大通桥监督刑部候补郎中
# 22162             陸軍部軍衡司賞賚科科員陸軍步隊協軍校             陆军部军衡司赏赉科科员陆军步队协军校
#
# [22163 rows x 7 columns]

# %% [markdown]
# # Add posting_office_only_exact_result to posting_office_only_office_source

# %%
# use cbdb_office_name as the key to assign cbdb_office_id to posting_office_only_office_source

posting_office_only_office_source = pd.merge(posting_office_only_office_source, posting_office_only_exact_result, on="cbdb_office_name_sim", how="left")
posting_office_only_office_source
# Out:
#        jigou_1  jigou_2 jigou_3      guanzhi     id  \
# 0           刑部     額外司員                   主事      0
# 1           戶部     額外司員              主事廣西司行走      1
# 2           禮部     額外司員                   主事      2
# 3          欽天監      天文科                  靈臺郎      3
# 4          鴻臚寺     額外序班                 額外序班      4
# ...        ...      ...     ...          ...    ...
# 22158  京師高等審判廳  京師地方檢察廳    額外廳員  額外廳員候補從六品推檢  10696
# 22159      軍諮處      第一廳     第四科         兼署科長  10708
# 22160      軍諮府      第一廳     第四科         兼署科長  10709
# 22161       戶部     倉場總督    各倉監督  大通橋監督刑部候補郎中  10710
# 22162      陸軍部      軍衡司     賞賚科    科員陸軍步隊協軍校  10727
#
#                     cbdb_office_name           cbdb_office_name_sim  \
# 0                               刑部主事                           刑部主事
# 1                          戶部主事廣西司行走                      户部主事广西司行走
# 2                               禮部主事                           礼部主事
# 3                             欽天監靈臺郎                         钦天监灵台郎
# 4                            鴻臚寺額外序班                        鸿胪寺额外序班
# ...                              ...                            ...
# 22158  京師高等審判廳京師地方檢察廳額外廳員額外廳員候補從六品推檢  京师高等审判厅京师地方检察厅额外厅员额外厅员候补从六品推检
# 22159                  軍諮處第一廳第四科兼署科長                  军咨处第一厅第四科兼署科长
# 22160                  軍諮府第一廳第四科兼署科長                  军咨府第一厅第四科兼署科长
# 22161          戶部倉場總督各倉監督大通橋監督刑部候補郎中          户部仓场总督各仓监督大通桥监督刑部候补郎中
# 22162             陸軍部軍衡司賞賚科科員陸軍步隊協軍校             陆军部军衡司赏赉科科员陆军步队协军校
#
#        cbdb_office_id
# 0             86386.0
# 1                 NaN
# 2             83726.0
# 3                 NaN
# 4                 NaN
# ...               ...
# 22158             NaN
# 22159             NaN
# 22160             NaN
# 22161             NaN
# 22162             NaN
#
# [22163 rows x 8 columns]

# %%
# how many office_id is not null
posting_office_only_office_source[posting_office_only_office_source["cbdb_office_id"].notnull()]
# Out:
#       jigou_1 jigou_2 jigou_3 guanzhi     id cbdb_office_name  \
# 0          刑部    額外司員              主事      0             刑部主事
# 2          禮部    額外司員              主事      2             禮部主事
# 7          戶部    額外司員              主事      7             戶部主事
# 8          刑部    額外司員             員外郞      8            刑部員外郞
# 23         刑部    額外司員              郎中     23             刑部郎中
# ...       ...     ...     ...     ...    ...              ...
# 20004      工部     都水司              主事  10515          工部都水司主事
# 20079      刑部     湖廣司             員外郎  10592         刑部湖廣司員外郎
# 20090      戶部     江西司             員外郎  10603         戶部江西司員外郎
# 20112      禮部     鑄印局           掌印員外郎  10626       禮部鑄印局掌印員外郎
# 20138      刑部     廣東司              主事  10656          刑部廣東司主事
#
#       cbdb_office_name_sim  cbdb_office_id
# 0                     刑部主事         86386.0
# 2                     礼部主事         83726.0
# 7                     户部主事         82595.0
# 8                    刑部员外郞         86368.0
# 23                    刑部郎中         86301.0
# ...                    ...             ...
# 20004              工部都水司主事         81705.0
# 20079             刑部湖广司员外郎         86283.0
# 20090             户部江西司员外郎         82509.0
# 20112           礼部铸印局掌印员外郎         83731.0
# 20138              刑部广东司主事         86261.0
#
# [1287 rows x 8 columns]

# %%
# rename posting_office_only_office_source by the existing keys in column_name_pairs
for column_name, new_column_name in column_name_pairs.items():
    if column_name in posting_office_only_office_source.columns:
        posting_office_only_office_source[new_column_name] = posting_office_only_office_source[column_name].apply(converter.convert)
        posting_office_only_office_source = posting_office_only_office_source.drop(columns=[column_name])

posting_office_only_office_source
# Out:
#           id               cbdb_office_name           cbdb_office_name_sim  \
# 0          0                           刑部主事                           刑部主事
# 1          1                      戶部主事廣西司行走                      户部主事广西司行走
# 2          2                           禮部主事                           礼部主事
# 3          3                         欽天監靈臺郎                         钦天监灵台郎
# 4          4                        鴻臚寺額外序班                        鸿胪寺额外序班
# ...      ...                            ...                            ...
# 22158  10696  京師高等審判廳京師地方檢察廳額外廳員額外廳員候補從六品推檢  京师高等审判厅京师地方检察厅额外厅员额外厅员候补从六品推检
# 22159  10708                  軍諮處第一廳第四科兼署科長                  军咨处第一厅第四科兼署科长
# 22160  10709                  軍諮府第一廳第四科兼署科長                  军咨府第一厅第四科兼署科长
# 22161  10710          戶部倉場總督各倉監督大通橋監督刑部候補郎中          户部仓场总督各仓监督大通桥监督刑部候补郎中
# 22162  10727             陸軍部軍衡司賞賚科科員陸軍步隊協軍校             陆军部军衡司赏赉科科员陆军步队协军校
#
#        cbdb_office_id jigou_1_sim jigou_2_sim jigou_3_sim  guanzhi_sim
# 0             86386.0          刑部        额外司员                       主事
# 1                 NaN          户部        额外司员                  主事广西司行走
# 2             83726.0          礼部        额外司员                       主事
# 3                 NaN         钦天监         天文科                      灵台郎
# 4                 NaN         鸿胪寺        额外序班                     额外序班
# ...               ...         ...         ...         ...          ...
# 22158             NaN     京师高等审判厅     京师地方检察厅        额外厅员  额外厅员候补从六品推检
# 22159             NaN         军咨处         第一厅         第四科         兼署科长
# 22160             NaN         军咨府         第一厅         第四科         兼署科长
# 22161             NaN          户部        仓场总督        各仓监督  大通桥监督刑部候补郎中
# 22162             NaN         陆军部         军衡司         赏赉科    科员陆军步队协军校
#
# [22163 rows x 8 columns]

# %%
# Using jigou_1_sim	jigou_2_sim	jigou_3_sim	guanzhi_sim as the key, if there are multiple keys, use the one with largest id number
posting_office_only_office_source = posting_office_only_office_source[posting_office_only_office_source["cbdb_office_id"].notnull()]
posting_office_only_office_source = posting_office_only_office_source.sort_values("id", ascending=False)
posting_office_only_office_source = posting_office_only_office_source.drop_duplicates(["jigou_1_sim", "jigou_2_sim", "jigou_3_sim", "guanzhi_sim"])
posting_office_only_office_source
# Out:
#           id cbdb_office_name cbdb_office_name_sim  cbdb_office_id  \
# 10723  10723             刑部主事                 刑部主事         86386.0
# 10694  10694             中營遊擊                 中营游击         87595.0
# 10658  10658           刑部额外主事               刑部额外主事         86244.0
# 10656  10656             刑部主事                 刑部主事         86386.0
# 20112  10626       禮部鑄印局掌印員外郎           礼部铸印局掌印员外郎         83731.0
# ...      ...              ...                  ...             ...
# 23        23             刑部郎中                 刑部郎中         86301.0
# 8          8            刑部員外郞                刑部员外郞         86368.0
# 7          7             戶部主事                 户部主事         82595.0
# 2          2             禮部主事                 礼部主事         83726.0
# 0          0             刑部主事                 刑部主事         86386.0
#
#       jigou_1_sim jigou_2_sim jigou_3_sim guanzhi_sim
# 10723          刑部         陕甘司                      主事
# 10694                                            中营游击
# 10658          刑部         江西司                    额外主事
# 10656          刑部         广东司                      主事
# 20112          礼部         铸印局                   掌印员外郎
# ...           ...         ...         ...         ...
# 23             刑部        额外司员                      郎中
# 8              刑部        额外司员                     员外郞
# 7              户部        额外司员                      主事
# 2              礼部        额外司员                      主事
# 0              刑部        额外司员                      主事
#
# [894 rows x 8 columns]

# %%
# save posting_office_only_office_source

posting_office_only_office_source.to_excel("posting_office_only_office_source.xlsx", index=False)

# %%
## merge posting_office_only_office_source to df_new
# drop id,
posting_office_only_office_source = posting_office_only_office_source.drop(columns=["id", "cbdb_office_name_sim"])
posting_office_only_office_source = posting_office_only_office_source.rename(columns={"cbdb_office_name":"cbdb_posting_office_name", "cbdb_office_id":"cbdb_posting_office_id"})
df_new = pd.merge(df_new, posting_office_only_office_source, on=["jigou_1_sim", "jigou_2_sim", "jigou_3_sim", "guanzhi_sim"], how="left")
df_new
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 2603899  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2603900  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 2603901  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2603902  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2603903  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... jigou_2_sim jigou_3_sim guanzhi_sim  \
# 0           阿迷州              學正  ...         阿迷州                      学正
# 1           阿迷州              學正  ...         阿迷州                      学正
# 2           阿迷州              學正  ...         阿迷州                      学正
# 3         翰林院編修              空白  ...       翰林院编修                      空白
# 4         翰林院編修              空白  ...       翰林院编修                      空白
# ...         ...     ...     ...  ...         ...         ...         ...
# 2603899    浙江衛所     金衢所    領運千總  ...        浙江卫所         金衢所        领运千总
# 2603900    江南衛所     江淮衛  三幫領運千總  ...        江南卫所         江淮卫      三帮领运千总
# 2603901     甕安縣              典史  ...         罋安县                      典史
# 2603902     瑞昌縣           肇陳口巡检  ...         瑞昌县                   肇陈口巡检
# 2603903                    盐捕州判  ...                                盐捕州判
#
#         ren_sheng_sim ren_xian_sim cbdb_biog_addr_id cbdb_biog_addr_name  \
# 0                  云南                            NaN                 NaN
# 1                  云南                            NaN                 NaN
# 2                              云南府            8915.0                 云南府
# 3                  贵州           贵筑            8879.0                  贵筑
# 4                  贵州           贵筑            8879.0                  贵筑
# ...               ...          ...               ...                 ...
# 2603899            湖北           孝感            8213.0                  孝感
# 2603900            湖北                            NaN                 NaN
# 2603901            浙江           上虞            7687.0                  上虞
# 2603902            顺天           大兴            7213.0                  大兴
# 2603903            湖北           江夏            8215.0                  江夏
#
#         cbdb_biog_addr_belong cbdb_posting_office_name cbdb_posting_office_id
# 0                         NaN                      NaN                    NaN
# 1                         NaN                      NaN                    NaN
# 2                                                  NaN                    NaN
# 3                         贵州省                      NaN                    NaN
# 4                         贵州省                      NaN                    NaN
# ...                       ...                      ...                    ...
# 2603899                   湖北省                      NaN                    NaN
# 2603900                   NaN                      NaN                    NaN
# 2603901                   浙江省                      NaN                    NaN
# 2603902                   顺天府                      NaN                    NaN
# 2603903                   湖北省                      NaN                    NaN
#
# [2603904 rows x 36 columns]

# %%
# count cbdb_center_office_name is not null
df_new[df_new["cbdb_posting_office_name"].notnull()]
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 2655     1872.25     2.0  24582.0      1900701.0  福建省
# 3805     1882.00     1.0  22166.0      2449659.0  甘肅省
# 3848     1872.25     2.0  22142.0      1898261.0  甘肅省
# 4817     1860.00     1.0  26406.0      1422311.0  江西省
# 4818     1859.75     4.0  26405.0      1400805.0  江西省
# ...          ...     ...      ...            ...  ...          ...     ...
# 2595503  1786.00     1.0  25508.0        93867.0  浙江省
# 2595504  1788.00     1.0  25488.0       114261.0  浙江省
# 2595536  1788.00     1.0  25073.0       113846.0  浙江省
# 2595537  1786.00     1.0  25092.0        93451.0  浙江省
# 2601263  1803.00     1.0  26653.0       258476.0  江南省
#
#         jigou_2 jigou_3 guanzhi  ... jigou_2_sim jigou_3_sim guanzhi_sim  \
# 2655                       右營遊撃  ...                                右营游击
# 3805                         千總  ...                                  千总
# 3848                         千總  ...                                  千总
# 4817                         千總  ...                                  千总
# 4818                         千總  ...                                  千总
# ...         ...     ...     ...  ...         ...         ...         ...
# 2595503                      千總  ...                                  千总
# 2595504                      千總  ...                                  千总
# 2595536                      千總  ...                                  千总
# 2595537                      千總  ...                                  千总
# 2601263                      千總  ...                                  千总
#
#         ren_sheng_sim ren_xian_sim cbdb_biog_addr_id cbdb_biog_addr_name  \
# 2655               江西                            NaN                 NaN
# 3805               甘肃                            NaN                 NaN
# 3848               甘肃                            NaN                 NaN
# 4817               江西                            NaN                 NaN
# 4818               江西                            NaN                 NaN
# ...               ...          ...               ...                 ...
# 2595503            浙江                            NaN                 NaN
# 2595504            浙江                            NaN                 NaN
# 2595536            江南                            NaN                 NaN
# 2595537            浙江                            NaN                 NaN
# 2601263            江苏           武进            7530.0                  武进
#
#         cbdb_biog_addr_belong cbdb_posting_office_name cbdb_posting_office_id
# 2655                      NaN                     右營遊擊                87024.0
# 3805                      NaN                       千總                84478.0
# 3848                      NaN                       千總                84478.0
# 4817                      NaN                       千總                84478.0
# 4818                      NaN                       千總                84478.0
# ...                       ...                      ...                    ...
# 2595503                   NaN                       千總                84478.0
# 2595504                   NaN                       千總                84478.0
# 2595536                   NaN                       千總                84478.0
# 2595537                   NaN                       千總                84478.0
# 2601263                   江苏省                       千總                84478.0
#
# [10095 rows x 36 columns]

# %% [markdown]
# ## Load posting data with address
#
# - code_addr_for_office_with_addr_result
# - code_office_for_office_with_addr_result

# %% [markdown]
# ### Work on code addr for office with addr

# %%
code_addr_for_office_with_addr_result = pd.read_excel(INPUT_CODE_ADDR_FOR_OFFICE_WITH_ADDR_RESULT_PATH)
code_office_for_office_with_addr_result = pd.read_excel(INPUT_CODE_OFFICE_FOR_OFFICE_WITH_ADDR_RESULT_PATH)

# %%
code_addr_for_office_with_addr_result = code_addr_for_office_with_addr_result.fillna("")
code_addr_for_office_with_addr_result = code_addr_for_office_with_addr_result[code_addr_for_office_with_addr_result["match_type"].isin(exact_flag)]
code_addr_for_office_with_addr_result = code_addr_for_office_with_addr_result.rename(columns={"cbdb_id":"cbdb_posting_addr_id", "cbdb_addr_name":"cbdb_posting_addr_name", "cbdb_belong":"cbdb_posting_addr_belong"})
code_addr_for_office_with_addr_result = code_addr_for_office_with_addr_result.drop(columns=["id", "dy", "time", "match_type"])
code_addr_for_office_with_addr_result
# Out:
#       addr_name addr_belong cbdb_posting_addr_id cbdb_posting_addr_name  \
# 733          嘉兴        浙江卫所               7620.0                     嘉兴
# 1738         嘉兴        总漕部院               7620.0                     嘉兴
# 2659         嘉兴         江南省               7620.0                     嘉兴
# 2933        阿迷州         临安府               6867.0                    阿迷州
# 2943        云龙州         大理府               6871.0                    云龙州
# ...         ...         ...                  ...                    ...
# 14844   喀喇沙尔直隶厅        甘肃新疆              20669.0                喀喇沙尔直隶厅
# 14848     镇沅直隶厅          云南               8928.0                  镇沅直隶厅
# 14849        新疆          甘肃             700162.0                     新疆
# 14857       长春厅          盛京              20624.0                    长春厅
# 14860        盛京          盛京              20656.0                     盛京
#
#       cbdb_posting_addr_belong
# 733
# 1738
# 2659
# 2933                       临安府
# 2943                       大理府
# ...                        ...
# 14844
# 14848                      云南省
# 14849
# 14857
# 14860
#
# [2121 rows x 5 columns]

# %%
posting_office_addr_addr_source = pd.read_excel(INPUT_POSTING_OFFICE_ADDR_ADDR_CODING_PATH)
posting_office_addr_addr_source = posting_office_addr_addr_source.fillna("")
posting_office_addr_addr_source["addr_name"] = posting_office_addr_addr_source["addr_name"].apply(converter.convert)
posting_office_addr_addr_source["addr_belong"] = posting_office_addr_addr_source["addr_belong"].apply(converter.convert)
posting_office_addr_addr_source
# Out:
#        diqu jigou_1 jigou_2 jigou_3     id dy addr_name addr_belong     time
# 0       湖南省      提標    永順協標     鎮溪營     94  清       镇溪营        永顺协标  no_info
# 1       湖南省    鎮筸鎮標    乾州協標     鎮溪營    101  清       镇溪营        干州协标  no_info
# 2       江蘇省    總漕部院    直隸衛所    天津左所    157  清      天津左所        直隶卫所  no_info
# 3       廣東省    南韶鎮標   三江口協標      左營    175  清        左营       三江口协标  no_info
# 4       四川省     提法司     巡警道     總務科    239  清       总务科         巡警道  no_info
# ...     ...     ...     ...     ...    ... ..       ...         ...      ...
# 14861  甘肅新疆    邊務大臣                  87626  清      边务大臣        甘肃新疆  no_info
# 14862    盛京      兵部                  87680  清        兵部          盛京  no_info
# 14863    江蘇    按察使司                  87692  清      按察使司          江苏  no_info
# 14864  甘肅新疆   哈甯直隸廳                  87869  清     哈宁直隶厅        甘肃新疆  no_info
# 14865    山東    總漕部院                  87966  清      总漕部院          山东  no_info
#
# [14866 rows x 9 columns]

# %%
posting_office_addr_addr_source = pd.merge(posting_office_addr_addr_source, code_addr_for_office_with_addr_result, on=["addr_name", "addr_belong"], how="left")
posting_office_addr_addr_source = posting_office_addr_addr_source[posting_office_addr_addr_source["cbdb_posting_addr_id"].notnull()]
posting_office_addr_addr_source = posting_office_addr_addr_source.sort_values("id", ascending=False)
posting_office_addr_addr_source = posting_office_addr_addr_source.drop_duplicates(["diqu", "jigou_1", "jigou_2", "jigou_3"])
posting_office_addr_addr_source = posting_office_addr_addr_source.drop(columns=["id", "dy", "addr_name", "addr_belong", "time"])
posting_office_addr_addr_source
# Out:
#        diqu  jigou_1 jigou_2 jigou_3 cbdb_posting_addr_id  \
# 15508    盛京       盛京                              20656.0
# 15505    盛京      長春廳                              20624.0
# 15497    甘肅       新疆                             700162.0
# 15496    雲南    鎮沅直隸廳                               8928.0
# 15492  甘肅新疆  喀喇沙爾直隸廳                              20669.0
# ...     ...      ...     ...     ...                  ...
# 13692   雲南省    鎮沅直隸廳                               8928.0
# 13690    雲南      楚雄府     黑鹽井                       8916.0
# 13689   雲南省      楚雄府     黑鹽井                       8916.0
# 13688   雲南省      東川府     會澤縣                       8918.0
# 13687   雲南省      臨安府     阿迷州                       8924.0
#
#       cbdb_posting_addr_name cbdb_posting_addr_belong
# 15508                     盛京
# 15505                    长春厅
# 15497                     新疆
# 15496                  镇沅直隶厅                      云南省
# 15492                喀喇沙尔直隶厅
# ...                      ...                      ...
# 13692                  镇沅直隶厅                      云南省
# 13690                    楚雄府                      云南省
# 13689                    楚雄府                      云南省
# 13688                    东川府                      云南省
# 13687                    临安府                      云南省
#
# [1571 rows x 7 columns]

# %%
df_new = pd.merge(df_new, posting_office_addr_addr_source, on=["diqu", "jigou_1", "jigou_2", "jigou_3"], how="left")
df_new
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 2603899  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 2603900  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 2603901  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 2603902  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 2603903  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... ren_sheng_sim ren_xian_sim  \
# 0           阿迷州              學正  ...            云南
# 1           阿迷州              學正  ...            云南
# 2           阿迷州              學正  ...                        云南府
# 3         翰林院編修              空白  ...            贵州           贵筑
# 4         翰林院編修              空白  ...            贵州           贵筑
# ...         ...     ...     ...  ...           ...          ...
# 2603899    浙江衛所     金衢所    領運千總  ...            湖北           孝感
# 2603900    江南衛所     江淮衛  三幫領運千總  ...            湖北
# 2603901     甕安縣              典史  ...            浙江           上虞
# 2603902     瑞昌縣           肇陳口巡检  ...            顺天           大兴
# 2603903                    盐捕州判  ...            湖北           江夏
#
#         cbdb_biog_addr_id cbdb_biog_addr_name cbdb_biog_addr_belong  \
# 0                     NaN                 NaN                   NaN
# 1                     NaN                 NaN                   NaN
# 2                  8915.0                 云南府
# 3                  8879.0                  贵筑                   贵州省
# 4                  8879.0                  贵筑                   贵州省
# ...                   ...                 ...                   ...
# 2603899            8213.0                  孝感                   湖北省
# 2603900               NaN                 NaN                   NaN
# 2603901            7687.0                  上虞                   浙江省
# 2603902            7213.0                  大兴                   顺天府
# 2603903            8215.0                  江夏                   湖北省
#
#         cbdb_posting_office_name cbdb_posting_office_id cbdb_posting_addr_id  \
# 0                            NaN                    NaN               8924.0
# 1                            NaN                    NaN               8924.0
# 2                            NaN                    NaN               8924.0
# 3                            NaN                    NaN                  NaN
# 4                            NaN                    NaN                  NaN
# ...                          ...                    ...                  ...
# 2603899                      NaN                    NaN                  NaN
# 2603900                      NaN                    NaN                  NaN
# 2603901                      NaN                    NaN                  NaN
# 2603902                      NaN                    NaN                  NaN
# 2603903                      NaN                    NaN                  NaN
#
#         cbdb_posting_addr_name cbdb_posting_addr_belong
# 0                          临安府                      云南省
# 1                          临安府                      云南省
# 2                          临安府                      云南省
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 2603899                    NaN                      NaN
# 2603900                    NaN                      NaN
# 2603901                    NaN                      NaN
# 2603902                    NaN                      NaN
# 2603903                    NaN                      NaN
#
# [2603904 rows x 39 columns]

# %%
# count how many cbdb_posting_addr_id is not null
df_new[df_new["cbdb_posting_addr_id"].notnull()]
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 5        1885.50     3.0  12606.0      2642022.0  雲南省           螳螂     東川府
# 7        1877.25     2.0  14616.0      2164909.0  雲南省                  楚雄府
# ...          ...     ...      ...            ...  ...          ...     ...
# 2603887  1760.75     4.0  10999.0        11000.0  四川省           劍閣     保寧府
# 2603888  1760.75     4.0   8979.0         8980.0  山東省           千乘     武定府
# 2603889  1760.75     4.0  12524.0        12526.0  雲南省           昆州     雲南府
# 2603892  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
# 2603893  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
#
#         jigou_2 jigou_3   guanzhi  ... ren_sheng_sim ren_xian_sim  \
# 0           阿迷州                學正  ...            云南
# 1           阿迷州                學正  ...            云南
# 2           阿迷州                學正  ...                        云南府
# 5           會澤縣                知縣  ...            四川           邛州
# 7           黑鹽井           黑鹽井鹽課大使  ...            四川           邛州
# ...         ...     ...       ...  ...           ...          ...
# 2603887      劍州              武連驿丞  ...            江苏           上元
# 2603888      濱州          县丞管吏目事军功  ...            浙江           会稽
# 2603889     昆明縣                县丞  ...            江西           安义
# 2603892     金壇縣                典史  ...            浙江           慈溪
# 2603893     金壇縣                典史  ...            浙江           慈溪
#
#         cbdb_biog_addr_id cbdb_biog_addr_name cbdb_biog_addr_belong  \
# 0                     NaN                 NaN                   NaN
# 1                     NaN                 NaN                   NaN
# 2                  8915.0                 云南府
# 5                     NaN                 NaN                   NaN
# 7                     NaN                 NaN                   NaN
# ...                   ...                 ...                   ...
# 2603887            7558.0                  上元                   江苏省
# 2603888            7685.0                  会稽                   浙江省
# 2603889            7872.0                  安义                   江西省
# 2603892            7629.0                  慈溪                   浙江省
# 2603893            7629.0                  慈溪                   浙江省
#
#         cbdb_posting_office_name cbdb_posting_office_id cbdb_posting_addr_id  \
# 0                            NaN                    NaN               8924.0
# 1                            NaN                    NaN               8924.0
# 2                            NaN                    NaN               8924.0
# 5                            NaN                    NaN               8918.0
# 7                            NaN                    NaN               8916.0
# ...                          ...                    ...                  ...
# 2603887                      NaN                    NaN               8762.0
# 2603888                      NaN                    NaN               7974.0
# 2603889                      NaN                    NaN               8915.0
# 2603892                      NaN                    NaN               7550.0
# 2603893                      NaN                    NaN               7550.0
#
#         cbdb_posting_addr_name cbdb_posting_addr_belong
# 0                          临安府                      云南省
# 1                          临安府                      云南省
# 2                          临安府                      云南省
# 5                          东川府                      云南省
# 7                          楚雄府                      云南省
# ...                        ...                      ...
# 2603887                     剑州                      保宁府
# 2603888                     滨州                      山东省
# 2603889                    云南府                      云南省
# 2603892                    镇江府                      江苏省
# 2603893                    镇江府                      江苏省
#
# [455352 rows x 39 columns]

# %% [markdown]
# ### Work on code office for office with addr

# %%
code_office_for_office_with_addr_result
# Out:
#        office_id office_name office_dy  cbdb_office_id cbdb_office_name  \
# 0              0          学正         清           86495               学正
# 1              1          知县         清           87473               知县
# 2              2     按板井盐课大使         清           80871               大使
# 3              3     黑盐井盐课大使         清           80871               大使
# 4              6       把总驻招远         清           80072               把总
# ...          ...         ...       ...             ...              ...
# 22210      88175     守备充鱼雷二副         清           84983               守备
# 22211      88205    五品蓝翎三队把总         清           85745             五品蓝翎
# 22212      88217    蓝翎五品顶戴守备         清           84983               守备
# 22213      88246  中军都司兼管圆明园汛         清           87555             中军都司
# 22214      88248       广宁汛守备         清           86594              汛守备
#
#       match_type
# 0          exact
# 1          exact
# 2        partial
# 3        partial
# 4        partial
# ...          ...
# 22210    partial
# 22211    partial
# 22212    partial
# 22213    partial
# 22214    partial
#
# [22215 rows x 6 columns]

# %%
prepare_code_office_for_office_with_addr_result = code_office_for_office_with_addr_result[code_office_for_office_with_addr_result["match_type"].isin(exact_flag)]
prepare_code_office_for_office_with_addr_result
# Out:
#        office_id office_name office_dy  cbdb_office_id cbdb_office_name  \
# 0              0          学正         清           86495               学正
# 1              1          知县         清           87473               知县
# 5              7        中军守备         清           87559             中军守备
# 9             13          典史         清           80944               典史
# 10            18          教授         清           83076               教授
# ...          ...         ...       ...             ...              ...
# 21679      84283        领队大臣         清           83881             领队大臣
# 21749      84843      巡捕左营游击         清           86518           巡捕左营游击
# 21779      85134      巡捕北营游击         清           86507           巡捕北营游击
# 21937      86413      漕标中军副将         清           80568           漕标中军副将
# 22120      87680       八品笔帖式         清           80027            八品笔帖式
#
#       match_type
# 0          exact
# 1          exact
# 5          exact
# 9          exact
# 10         exact
# ...          ...
# 21679      exact
# 21749      exact
# 21779      exact
# 21937      exact
# 22120      exact
#
# [237 rows x 6 columns]

# %%
code_office_for_office_with_addr_source = pd.read_excel(INPUT_POSTING_OFFICE_ADDR_OFFICE_CODING_PATH)
code_office_for_office_with_addr_source["guanzhi_sim"] = code_office_for_office_with_addr_source["guanzhi"].apply(converter.convert)
code_office_for_office_with_addr_source
# Out:
#           id dy     guanzhi guanzhi_sim
# 0          0  清          學正          学正
# 1          1  清          知縣          知县
# 2          2  清     按板井鹽課大使     按板井盐课大使
# 3          3  清     黑鹽井鹽課大使     黑盐井盐课大使
# 4          6  清       把總駐招遠       把总驻招远
# ...      ... ..         ...         ...
# 23451  88205  清    五品藍翎三隊把總    五品蓝翎三队把总
# 23452  88213  清      大政殿六品官      大政殿六品官
# 23453  88217  清    藍翎五品頂戴守備    蓝翎五品顶戴守备
# 23454  88246  清  中軍都司兼管圓眀園汛  中军都司兼管圆明园汛
# 23455  88248  清       廣寧汛守備       广宁汛守备
#
# [23456 rows x 4 columns]

# %%
# Don't need prepare_code_office_for_office_with_addr_result for now
prepare_code_office_for_office_with_addr_result = prepare_code_office_for_office_with_addr_result.drop(columns=["office_id", "office_dy", "match_type"])
prepare_code_office_for_office_with_addr_result = prepare_code_office_for_office_with_addr_result.rename(columns={"cbdb_office_name":"guanzhi_sim"})
prepare_code_office_for_office_with_addr_result = prepare_code_office_for_office_with_addr_result.rename(columns={"cbdb_office_id":"cbdb_posting_office_id", "office_name":"cbdb_posting_office_name"})
prepare_code_office_for_office_with_addr_result
# Out:
#       cbdb_posting_office_name  cbdb_posting_office_id guanzhi_sim
# 0                           学正                   86495          学正
# 1                           知县                   87473          知县
# 5                         中军守备                   87559        中军守备
# 9                           典史                   80944          典史
# 10                          教授                   83076          教授
# ...                        ...                     ...         ...
# 21679                     领队大臣                   83881        领队大臣
# 21749                   巡捕左营游击                   86518      巡捕左营游击
# 21779                   巡捕北营游击                   86507      巡捕北营游击
# 21937                   漕标中军副将                   80568      漕标中军副将
# 22120                    八品笔帖式                   80027       八品笔帖式
#
# [237 rows x 3 columns]

# %%
# replace nan by "" for df_new
df_new = df_new.fillna("")

# %%
# using prepare_code_office_for_office_with_addr_result's cbdb_posting_office_name to fill in df_new's cbdb_posting_office_id and cbdb_posting_office_name while cbdb_posting_office_name is NaN

# First, merge df_new with prepare_code_office_for_office_with_addr_result
df_merged = df_new.merge(
    prepare_code_office_for_office_with_addr_result[['cbdb_posting_office_id', 'cbdb_posting_office_name']],
    left_on='guanzhi_sim',
    right_on='cbdb_posting_office_name',
    how='left',
    suffixes=('', '_new')
)
df_merged
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 3123318  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 3123319  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 3123320  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 3123321  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 3123322  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... cbdb_biog_addr_id cbdb_biog_addr_name  \
# 0           阿迷州              學正  ...
# 1           阿迷州              學正  ...
# 2           阿迷州              學正  ...            8915.0                 云南府
# 3         翰林院編修              空白  ...            8879.0                  贵筑
# 4         翰林院編修              空白  ...            8879.0                  贵筑
# ...         ...     ...     ...  ...               ...                 ...
# 3123318    浙江衛所     金衢所    領運千總  ...            8213.0                  孝感
# 3123319    江南衛所     江淮衛  三幫領運千總  ...
# 3123320     甕安縣              典史  ...            7687.0                  上虞
# 3123321     瑞昌縣           肇陳口巡检  ...            7213.0                  大兴
# 3123322                    盐捕州判  ...            8215.0                  江夏
#
#         cbdb_biog_addr_belong cbdb_posting_office_name cbdb_posting_office_id  \
# 0
# 1
# 2
# 3                         贵州省
# 4                         贵州省
# ...                       ...                      ...                    ...
# 3123318                   湖北省
# 3123319
# 3123320                   浙江省
# 3123321                   顺天府
# 3123322                   湖北省
#
#         cbdb_posting_addr_id cbdb_posting_addr_name cbdb_posting_addr_belong  \
# 0                     8924.0                    临安府                      云南省
# 1                     8924.0                    临安府                      云南省
# 2                     8924.0                    临安府                      云南省
# 3
# 4
# ...                      ...                    ...                      ...
# 3123318
# 3123319
# 3123320
# 3123321
# 3123322
#
#         cbdb_posting_office_id_new cbdb_posting_office_name_new
# 0                          86495.0                           学正
# 1                          86495.0                           学正
# 2                          86495.0                           学正
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 3123318                        NaN                          NaN
# 3123319                        NaN                          NaN
# 3123320                    80944.0                           典史
# 3123321                        NaN                          NaN
# 3123322                        NaN                          NaN
#
# [3123323 rows x 41 columns]

# %%
# print cbdb_posting_office_id_new is not null
df_merged[df_merged['cbdb_posting_office_id_new'].notnull()]
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 5        1885.50     3.0  12606.0      2642022.0  雲南省           螳螂     東川府
# 6        1885.50     3.0  12606.0      2642022.0  雲南省           螳螂     東川府
# ...          ...     ...      ...            ...  ...          ...     ...
# 3123310  1788.75     4.0   4734.0       120731.0  江南省           金沙     鎮江府
# 3123311  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
# 3123312  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
# 3123314  1760.75     4.0   8120.0         8121.0  湖南省           上少     辰州府
# 3123320  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
#
#         jigou_2 jigou_3 guanzhi  ... cbdb_biog_addr_id cbdb_biog_addr_name  \
# 0           阿迷州              學正  ...
# 1           阿迷州              學正  ...
# 2           阿迷州              學正  ...            8915.0                 云南府
# 5           會澤縣              知縣  ...
# 6           會澤縣              知縣  ...
# ...         ...     ...     ...  ...               ...                 ...
# 3123310     金壇縣              典史  ...            7629.0                  慈溪
# 3123311     金壇縣              典史  ...            7629.0                  慈溪
# 3123312     金壇縣              典史  ...            7629.0                  慈溪
# 3123314     沅陵縣              教諭  ...            8361.0                  慈利
# 3123320     甕安縣              典史  ...            7687.0                  上虞
#
#         cbdb_biog_addr_belong cbdb_posting_office_name cbdb_posting_office_id  \
# 0
# 1
# 2
# 5
# 6
# ...                       ...                      ...                    ...
# 3123310                   浙江省
# 3123311                   浙江省
# 3123312                   浙江省
# 3123314
# 3123320                   浙江省
#
#         cbdb_posting_addr_id cbdb_posting_addr_name cbdb_posting_addr_belong  \
# 0                     8924.0                    临安府                      云南省
# 1                     8924.0                    临安府                      云南省
# 2                     8924.0                    临安府                      云南省
# 5                     8918.0                    东川府                      云南省
# 6                     8918.0                    东川府                      云南省
# ...                      ...                    ...                      ...
# 3123310
# 3123311               7550.0                    镇江府                      江苏省
# 3123312               7550.0                    镇江府                      江苏省
# 3123314
# 3123320
#
#         cbdb_posting_office_id_new cbdb_posting_office_name_new
# 0                          86495.0                           学正
# 1                          86495.0                           学正
# 2                          86495.0                           学正
# 5                          87473.0                           知县
# 6                          87473.0                           知县
# ...                            ...                          ...
# 3123310                    80944.0                           典史
# 3123311                    80944.0                           典史
# 3123312                    80944.0                           典史
# 3123314                    83088.0                           教谕
# 3123320                    80944.0                           典史
#
# [1738077 rows x 41 columns]

# %%
# Now, update the 'cbdb_posting_office_id' column where it's ""
mask = df_merged['cbdb_posting_office_id'] == ""
# Fill in cbdb_posting_office_id and cbdb_posting_office_name
df_merged.loc[mask, 'cbdb_posting_office_id'] = df_merged.loc[mask, 'cbdb_posting_office_id_new']
df_merged.loc[mask, 'cbdb_posting_office_name'] = df_merged.loc[mask, 'cbdb_posting_office_name_new']

# %%
# print cbdb_posting_office_id_new is not null
df_merged[df_merged['cbdb_posting_office_id_new'].notnull()]
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 5        1885.50     3.0  12606.0      2642022.0  雲南省           螳螂     東川府
# 6        1885.50     3.0  12606.0      2642022.0  雲南省           螳螂     東川府
# ...          ...     ...      ...            ...  ...          ...     ...
# 3123310  1788.75     4.0   4734.0       120731.0  江南省           金沙     鎮江府
# 3123311  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
# 3123312  1788.00     1.0   4681.0       100294.0  江蘇省          調金沙     鎮江府
# 3123314  1760.75     4.0   8120.0         8121.0  湖南省           上少     辰州府
# 3123320  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
#
#         jigou_2 jigou_3 guanzhi  ... cbdb_biog_addr_id cbdb_biog_addr_name  \
# 0           阿迷州              學正  ...
# 1           阿迷州              學正  ...
# 2           阿迷州              學正  ...            8915.0                 云南府
# 5           會澤縣              知縣  ...
# 6           會澤縣              知縣  ...
# ...         ...     ...     ...  ...               ...                 ...
# 3123310     金壇縣              典史  ...            7629.0                  慈溪
# 3123311     金壇縣              典史  ...            7629.0                  慈溪
# 3123312     金壇縣              典史  ...            7629.0                  慈溪
# 3123314     沅陵縣              教諭  ...            8361.0                  慈利
# 3123320     甕安縣              典史  ...            7687.0                  上虞
#
#         cbdb_biog_addr_belong cbdb_posting_office_name cbdb_posting_office_id  \
# 0                                                   学正                86495.0
# 1                                                   学正                86495.0
# 2                                                   学正                86495.0
# 5                                                   知县                87473.0
# 6                                                   知县                87473.0
# ...                       ...                      ...                    ...
# 3123310                   浙江省                       典史                80944.0
# 3123311                   浙江省                       典史                80944.0
# 3123312                   浙江省                       典史                80944.0
# 3123314                                             教谕                83088.0
# 3123320                   浙江省                       典史                80944.0
#
#         cbdb_posting_addr_id cbdb_posting_addr_name cbdb_posting_addr_belong  \
# 0                     8924.0                    临安府                      云南省
# 1                     8924.0                    临安府                      云南省
# 2                     8924.0                    临安府                      云南省
# 5                     8918.0                    东川府                      云南省
# 6                     8918.0                    东川府                      云南省
# ...                      ...                    ...                      ...
# 3123310
# 3123311               7550.0                    镇江府                      江苏省
# 3123312               7550.0                    镇江府                      江苏省
# 3123314
# 3123320
#
#         cbdb_posting_office_id_new cbdb_posting_office_name_new
# 0                          86495.0                           学正
# 1                          86495.0                           学正
# 2                          86495.0                           学正
# 5                          87473.0                           知县
# 6                          87473.0                           知县
# ...                            ...                          ...
# 3123310                    80944.0                           典史
# 3123311                    80944.0                           典史
# 3123312                    80944.0                           典史
# 3123314                    83088.0                           教谕
# 3123320                    80944.0                           典史
#
# [1738077 rows x 41 columns]

# %%
merged_df = df_merged.drop(columns=['cbdb_posting_office_id_new', 'cbdb_posting_office_name_new'])
df_new = merged_df
df_new = df_new.reset_index(drop=True)
df_new
# Out:
#             year  season    xuhao  record_number diqu diming_titou jigou_1  \
# 0        1840.25     2.0  13174.0       788939.0  雲南省           河密     臨安府
# 1        1839.75     4.0  13191.0       775145.0  雲南省           河密     臨安府
# 2        1840.50     3.0  12481.0       802040.0  雲南省           ？甯     臨安府
# 3        1867.50     3.0    491.0      1607337.0   京師                翰林院衙門
# 4        1868.50     3.0    407.0      1671840.0   京師                翰林院衙門
# ...          ...     ...      ...            ...  ...          ...     ...
# 3123318  1797.00     1.0   5085.0       147534.0  江南省               總漕部院衙門
# 3123319  1788.00     1.0   4740.0       100353.0  江蘇省               總漕部院衙門
# 3123320  1760.75     4.0  13183.0        13185.0  貴州省           草塘     平越府
# 3123321  1760.75     4.0   6007.0         6007.0  江西省           亦烏     九江府
# 3123322  1760.75     4.0   8229.0         8230.0  湖南省                   郴州
#
#         jigou_2 jigou_3 guanzhi  ... ren_sheng_sim ren_xian_sim  \
# 0           阿迷州              學正  ...            云南
# 1           阿迷州              學正  ...            云南
# 2           阿迷州              學正  ...                        云南府
# 3         翰林院編修              空白  ...            贵州           贵筑
# 4         翰林院編修              空白  ...            贵州           贵筑
# ...         ...     ...     ...  ...           ...          ...
# 3123318    浙江衛所     金衢所    領運千總  ...            湖北           孝感
# 3123319    江南衛所     江淮衛  三幫領運千總  ...            湖北
# 3123320     甕安縣              典史  ...            浙江           上虞
# 3123321     瑞昌縣           肇陳口巡检  ...            顺天           大兴
# 3123322                    盐捕州判  ...            湖北           江夏
#
#         cbdb_biog_addr_id cbdb_biog_addr_name cbdb_biog_addr_belong  \
# 0
# 1
# 2                  8915.0                 云南府
# 3                  8879.0                  贵筑                   贵州省
# 4                  8879.0                  贵筑                   贵州省
# ...                   ...                 ...                   ...
# 3123318            8213.0                  孝感                   湖北省
# 3123319
# 3123320            7687.0                  上虞                   浙江省
# 3123321            7213.0                  大兴                   顺天府
# 3123322            8215.0                  江夏                   湖北省
#
#         cbdb_posting_office_name cbdb_posting_office_id cbdb_posting_addr_id  \
# 0                             学正                86495.0               8924.0
# 1                             学正                86495.0               8924.0
# 2                             学正                86495.0               8924.0
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...                  ...
# 3123318                      NaN                    NaN
# 3123319                      NaN                    NaN
# 3123320                       典史                80944.0
# 3123321                      NaN                    NaN
# 3123322                      NaN                    NaN
#
#         cbdb_posting_addr_name cbdb_posting_addr_belong
# 0                          临安府                      云南省
# 1                          临安府                      云南省
# 2                          临安府                      云南省
# 3
# 4
# ...                        ...                      ...
# 3123318
# 3123319
# 3123320
# 3123321
# 3123322
#
# [3123323 rows x 39 columns]

# %%
df_new.to_csv(OUTPUT_DATA, sep="\t", index=False)

# %%
# randomly pick 10k rows and save to a new file
df_new_sample = df_new.sample(n=10000)
df_new_sample.to_excel(OUTPUT_SAMPEL_DATA, index=False)

# %% [markdown]
# ## Last step, don't forget to remove NA for the big df
